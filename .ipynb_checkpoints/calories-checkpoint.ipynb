# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv("calories .csv")
df.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
df.shape
# Out:
# (15000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     42.789800    174.465133     74.966867     15.530600
# std    2.872851e+06     16.980264     14.258114     15.035657      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# 25%       88.000000     39.600000     35.000000
# 50%       96.000000     40.200000     79.000000
# 75%      103.000000     40.600000    138.000000
# max      128.000000     41.500000    314.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# User_ID       0
# Gender        0
# Age           0
# Height        0
# Weight        0
# Duration      0
# Heart_Rate    0
# Body_Temp     0
# Calories      0
# dtype: int64

# %%
#from sklearn.preproccesing import LabelEncoder
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Gender']=le.fit_transform(df['Gender'])

# %%
df.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363       1   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698       0   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863       1   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408       0   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927       0   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
for i in df.columns:
    sb.histplot(df[i])
    plt.show()

# %%
for i in df.columns:
    sb.boxplot(df[i])
    plt.show()

# %%
df=df.drop('User_ID',axis=1)

# %%
x=df[['Gender','Age','Height','Weight','Duration','Heart_Rate','Body_Temp']]
y=df['Calories']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.2)

# %%
sclar=StandardScaler()
x_train_sc=sclar.fit_transform(x_train)
x_test_sc=sclar.transform(x_test)

# %%
x_train
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 13172       1   39   202.0   104.0      19.0       100.0       40.3
# 12044       0   20   162.0    59.0      18.0        95.0       40.6
# 5328        0   23   164.0    65.0       4.0        77.0       38.8
# 6782        0   61   155.0    58.0      26.0       115.0       40.6
# 5099        0   21   155.0    58.0      24.0       106.0       40.7
# ...       ...  ...     ...     ...       ...         ...        ...
# 1412        0   54   169.0    68.0      14.0        94.0       40.0
# 10318       1   46   197.0    99.0       5.0        85.0       38.6
# 6097        1   21   198.0   101.0       7.0        95.0       39.2
# 8296        0   39   158.0    54.0      26.0        94.0       40.7
# 11166       0   69   172.0    69.0      17.0        93.0       40.8
#
# [3000 rows x 7 columns]

# %%
x_test
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 5639        0   69   187.0    76.0      23.0       108.0       40.6
# 4093        0   60   163.0    60.0      11.0        91.0       39.7
# 260         0   32   172.0    72.0       8.0        80.0       39.5
# 12564       1   52   170.0    76.0      16.0       100.0       40.5
# 11045       0   45   155.0    56.0      27.0       100.0       40.9
# ...       ...  ...     ...     ...       ...         ...        ...
# 9544        1   38   201.0   102.0      18.0       104.0       40.2
# 4819        0   54   158.0    60.0      14.0        95.0       40.1
# 5560        0   43   160.0    64.0      19.0       103.0       40.6
# 13468       1   77   187.0    91.0      30.0       107.0       41.0
# 5914        0   28   186.0    84.0      29.0       110.0       41.1
#
# [12000 rows x 7 columns]

# %%
model=SVC()
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
model.score(x_test, y_test)
# Out:
# 0.0105

# %%
from sklearn.metrics import accuracy_score

# %%
ypred = model.predict(x_test)

# %%
accuracy_score(y_test, ypred)
# Out:
# 0.0105
